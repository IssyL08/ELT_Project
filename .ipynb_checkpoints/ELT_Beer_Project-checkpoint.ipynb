# %%
# Dependencies
from splinter import Browser
from urllib.request import urlopen
from bs4 import BeautifulSoup as bs
import pandas as pd
import requests
import pymongo
from flask import Flask, render_template, redirect
from flask_pymongo import PyMongo

# %%
executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
beer_yeast_url='https://www.brewersfriend.com/yeasts/'
browser.visit(beer_yeast_url)

html = browser.html

news_soup = bs(html, 'html.parser')

# %%
beer_yeast_list= news_soup.find_all('table', class_='ui table striped browse-results')
beer_yeast_list
# Out:
# [<table class="ui table striped browse-results"><thead><tr><th><a href="?sortby=nameup">Yeast</a></th><th><a href="?sortby=laboratoryup">Laboratory</a></th><th><a href="?sortby=codeup">Code</a></th><th><a href="?sortby=typeup">Type</a></th><th><a href="?sortby=atup">Alcohol Tolerance</a></th><th><a href="?sortby=flocup">Flocculation</a></th><th><a href="?sortby=attenup">Attenuation</a></th><th><a href="?sortby=mintempup">Minimum Temp</a></th><th><a href="?sortby=maxtempup">Maximum Temp</a></th></tr></thead><tbody><tr><td><font style="font-size:16px;"><a href="/yeasts/white-labs-hornindal-kveik-ale-yeast/">White Labs - Hornindal Kveik Ale Yeast</a></font></td><td><font style="font-size:16px;"></font></td><td><font style="font-size:16px;"></font></td><td><font style="font-size:16px;">Norwegian Ales</font></td><td><font style="font-size:16px;">High</font></td><td><font style="font-size:16px;">High</font></td><td><font style="font-size:16px;">78%</font></td><td style="background: rgb(255
# ...

# %%
def get_all_yeast(html_soup):
    beer_yeast_list = []
    all_rows_in_html_page = html_soup.findAll("tr")
    for table_row in all_rows_in_html_page:
        if is_beer_entry(table_row):
            row_cells = table_row.findAll("td")
            beer_entry = {
                "Yeast":(row_cells[0].text),
                "Laboratory": row_cells[1].text,
                "Code": row_cells[2].text,
                "Type": row_cells[3].text,
                "Alcohol_Tolerancce": row_cells[4].text,
                "Flocculation": row_cells[5].text,
                "Attenuation": row_cells[6].text,    
                "Minimum_Temp": row_cells[7].text,
                "Maximum_Temp": row_cells[8].text
            }
            beers_list.append(beer_entry)
    return beer_yeast_list

# %%
html = urlopen('https://www.brewersfriend.com/yeasts/')
html_soup = bs(html, 'html.parser')
beer_yeast_list = get_all_beers(html_soup)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-940fa9be8808> in <module>
# ----> 1 html = urlopen('https://www.brewersfriend.com/yeasts/')
#       2 html_soup = bs(html, 'html.parser')
#       3 beer_yeast_list = get_all_beers(html_soup)
#
# NameError: name 'urlopen' is not defined

# %%
df = pd.DataFrame(beers_list)
df.head(5)
